# %%
import pandas as pd
import numpy as np
from os import path,listdir
location = path.join('..','derivatives','main_trial_level.csv')
sheet=pd.read_csv(location) #opening the excel file - trial level data
sheet.head()
# Out:
#    SubjNum  AgeGroup ExperimenterName  RunNum   Date             Time  \
# 0      401         2               xw       1  09_17  10:26:48.656000
# 1      401         2               xw       1  09_17  10:26:48.656000
# 2      401         2               xw       1  09_17  10:26:48.656000
# 3      401         2               xw       1  09_17  10:26:48.656000
# 4      401         2               xw       1  09_17  10:26:48.656000
#
#    TrialNum  TrialNumbydomdist Domain Magnitude        ...        Confidence  \
# 0         1                  1   GAIN      high        ...                75
# 1         2                  2   GAIN      high        ...                 8
# 2         3                  3   GAIN      high        ...                 9
# 3         4                  4   GAIN      high        ...                 9
# 4         5                  5   GAIN      high        ...                 8
#
#    ConfidenceST ConfidenceRT StockNumber BondNumber GenderJudgment  \
# 0  1.457099e+06     6.063213          19         16              1
# 1  1.457125e+06     4.995790          19         16              1
# 2  1.457146e+06     3.483579          19         16              1
# 3  1.457162e+06     2.075640          19         16              1
# 4  1.457177e+06     4.204404          19         16              1
#
#    TotalPayout  TrueProbGood  EstWithinRange? val_estdiff_valid
# 0           10      0.700000                1     -1.038193e-07
# 1           20      0.844828                0     -1.448277e-01
# 2           30      0.927027                0     -2.270271e-01
# 3           40      0.967365                0     -1.673651e-01
# 4           42      0.927027                0     -1.770271e-01
#
# [5 rows x 35 columns]

# %%
for index, row in sheet.iterrows():
    for i in row['SubjNum']:
        if row['TrialNum']==1: 
            print ("here")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-606367093842> in <module>
#       1 for index, row in sheet.iterrows():
# ----> 2     for i in row['SubjNum']:
#       3         if row['TrialNum']==1:
#       4             print ("here")
#       5
#
# TypeError: 'int' object is not iterable

# %%
#create variable that measures how often on the 1st trial people chose stock:
